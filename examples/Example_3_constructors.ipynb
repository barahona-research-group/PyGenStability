# %% [markdown]
# # Example 3: Trying various constructor options
#
# Each constructor encodes a different form of dynamics on the graph. Here, we exemplify each constructor and their outputs.

# %%
import networkx as nx

from pygenstability import run, plotting
import create_graph

# %%
# creating SBM

nx_graph, adjacency = create_graph.create_sbm()

# %% [markdown]
# ## Linearised matrix exponential (modularity)

# %%
all_results = run(adjacency, min_scale=-1, max_scale=1, n_scale = 30,constructor='linearized')
_ = plotting.plot_scan(all_results, use_plotly=False)
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 1169.32it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.04it/s]
# 100%|██████████| 30/30 [00:00<00:00, 205.28it/s]

# %%
# plot optimal partitions
plotting.plot_optimal_partitions(nx_graph, all_results)

# %% [markdown]
# ## Continuous scale - combinatorial Laplacian

# %%
all_results = run(adjacency, min_scale=-0.5, max_scale =.2, n_scale = 30,constructor='continuous_combinatorial')
_ = plotting.plot_scan(all_results, use_plotly=False)
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 30.98it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.01it/s]
# 100%|██████████| 30/30 [00:00<00:00, 115.87it/s]

# %%
# plot optimal partitions
plotting.plot_optimal_partitions(nx_graph, all_results)

# %% [markdown]
# ## Continuous scale - normalized Laplacian

# %%
all_results = run(adjacency, min_scale=-1, max_scale=1, n_scale = 30, constructor='continuous_normalized')
plotting.plot_scan(all_results, use_plotly=False)
# Out:
# 100%|██████████| 30/30 [00:01<00:00, 27.94it/s]
# 100%|██████████| 30/30 [00:09<00:00,  3.00it/s]
# 100%|██████████| 30/30 [00:00<00:00, 111.29it/s]
# [None,
#  <AxesSubplot:ylabel='Block NVI'>,
#  <AxesSubplot:ylabel='Stability'>,
#  <AxesSubplot:xlabel='$log_{10}(t)$', ylabel='NVI'>]

# %%
# plot optimal partitions
plotting.plot_optimal_partitions(nx_graph, all_results)
