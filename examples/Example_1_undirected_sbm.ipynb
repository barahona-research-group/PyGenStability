# %% [markdown]
# # Example 1: Markov Stability applied to undirected SBM

# %%
import networkx as nx

from pygenstability import run, plotting

import create_graph

# %%
# creating SBM

graph = create_graph.create_sbm()
# Out:
# /home/tc/OneDrive/Software/PyGenStability/examples/notebook/create_graph.py:35: FutureWarning:
#
# adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.

# %%
# run Markov Stability
all_results = run(graph, min_time=-1, max_time = 1, constructor='continuous_normalized')
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 32.03it/s]
# 100%|██████████| 20/20 [00:06<00:00,  3.01it/s]
# 100%|██████████| 20/20 [00:00<00:00, 116.11it/s]

# %%
# plot the results using plotly
plotting.plot_scan(all_results,use_plotly=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/tc/OneDrive/Software/PyGenStability/examples/notebook/Example_1_undirected_sbm.ipynb Cell 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/tc/OneDrive/Software/PyGenStability/examples/notebook/Example_1_undirected_sbm.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # plot the results using plotly
# ----> <a href='vscode-notebook-cell:/home/tc/OneDrive/Software/PyGenStability/examples/notebook/Example_1_undirected_sbm.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> plotting.plot_scan(all_results,use_plotly=True)
#
# File ~/OneDrive/Software/PyGenStability/src/pygenstability/plotting.py:45, in plot_scan(all_results, time_axis, figure_name, use_plotly, live, plotly_filename)
#      43 if use_plotly:
#      44     try:
# ---> 45         return plot_scan_plotly(all_results, live=live, filename=plotly_filename)
#      46     except ImportError as exc:
#      47         raise Exception(
#      48             "Plotly is not installed, install with: pip install pygenstabiliy[plotly]"
#      49         ) from exc
#
# File ~/OneDrive/Software/PyGenStability/src/pygenstability/plotting.py:188, in plot_scan_plotly(all_results, live, filename)
#     185     _plot(fig, filename=filename)
#     187 if live:
# --> 188     fig.show()
#     189 return fig, layout
#
# File ~/anaconda3/envs/pygenstability/lib/python3.10/site-packages/plotly/basedatatypes.py:3398, in BaseFigure.show(self, *args, **kwargs)
#    3365 """
#    3366 Show a figure using either the default renderer(s) or the renderer(s)
#    3367 specified by the renderer argument
#    (...)
#    3394 None
#    3395 """
#    3396 import plotly.io as pio
# -> 3398 return pio.show(self, *args, **kwargs)
#
# File ~/anaconda3/envs/pygenstability/lib/python3.10/site-packages/plotly/io/_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
# plot the results matplotlib
plotting.plot_scan(all_results,use_plotly=False)
# Out:
# [None,
#  <AxesSubplot:xlabel='$log_{10}(t)$', ylabel='NVI'>,
#  <AxesSubplot:ylabel='Stability'>,
#  <AxesSubplot:ylabel='Number of clusters'>,
#  <AxesSubplot:xlabel='$log_{10}(t)$', ylabel='Optimal Scale Criterion'>]

# %%
# convert into networkx and plot partition at time index t

nx_graph = nx.Graph(graph)
pos = nx.spring_layout(nx_graph, weight=None, scale=1)
for u in nx_graph:
    nx_graph.nodes[u]["pos"] = pos[u]

plotting.plot_single_community(nx_graph, all_results, time_id=12)

# %%
# plotting partitions at all times in './communities' folder

plotting.plot_communities(graph, all_results)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/tc/OneDrive/Software/PyGenStability/examples/notebook/Example_1_undirected_sbm.ipynb Cell 8 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/tc/OneDrive/Software/PyGenStability/examples/notebook/Example_1_undirected_sbm.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # plotting partitions at all times in './communities' folder
# ----> <a href='vscode-notebook-cell:/home/tc/OneDrive/Software/PyGenStability/examples/notebook/Example_1_undirected_sbm.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> plotting.plot_communities(graph, all_results)
#
# File ~/OneDrive/Software/PyGenStability/src/pygenstability/plotting.py:250, in plot_communities(graph, all_results, folder, edge_color, edge_width, ext)
#     248 for time_id in tqdm(range(len(all_results["times"]))):
#     249     plt.figure()
# --> 250     plot_single_community(
#     251         graph, all_results, time_id, edge_color=edge_color, edge_width=edge_width
#     252     )
#     253     plt.savefig(os.path.join(folder, "time_" + str(time_id) + ext), bbox_inches="tight")
#     254     plt.close()
#
# File ~/OneDrive/Software/PyGenStability/src/pygenstability/plotting.py:207, in plot_single_community(graph, all_results, time_id, edge_color, edge_width, node_size)
#     192 def plot_single_community(
#     193     graph, all_results, time_id, edge_color="0.5", edge_width=0.5, node_size=100
#     194 ):
#     195     """Plot the community structures for a given time.
#     196
#     197     Args:
#    (...)
#     205         ext (str): extension of figures files
#     206     """
# --> 207     pos = {u: graph.nodes[u]["pos"] for u in graph}
#     209     node_color = all_results["community_id"][time_id]
#     211     nx.draw_networkx_nodes(
#     212         graph,
#     213         pos=pos,
#    (...)
#     216         cmap=plt.get_cmap("tab20"),
#     217     )
#
# File ~/OneDrive/Software/PyGenStability/src/pygenstability/plotting.py:207, in <dictcomp>(.0)
#     192 def plot_single_community(
#     193     graph, all_results, time_id, edge_color="0.5", edge_width=0.5, node_size=100
#     194 ):
#     195     """Plot the community structures for a given time.
#     196
#     197     Args:
#    (...)
#     205         ext (str): extension of figures files
#     206     """
# --> 207     pos = {u: graph.nodes[u]["pos"] for u in graph}
#     209     node_color = all_results["community_id"][time_id]
#     211     nx.draw_networkx_nodes(
#     212         graph,
#     213         pos=pos,
#    (...)
#     216         cmap=plt.get_cmap("tab20"),
#     217     )
#
# File ~/anaconda3/envs/pygenstability/lib/python3.10/site-packages/scipy/sparse/_base.py:761, in spmatrix.__getattr__(self, attr)
#     759     return self.getnnz()
#     760 else:
# --> 761     raise AttributeError(attr + " not found")
#
# AttributeError: nodes not found
